# %%
import numpy as np
import pandas as pd

# 유클리드 거리 측정
def euclidean_distance(x, y):
	euclidean = []
	x = x.iloc[0].tolist()
	for idx, row in y.iterrows():
		e = np.sqrt(np.sum((x - row.values) ** 2))
		euclidean.append(e)
	euclidean = np.array(euclidean)
	return euclidean.reshape(1, -1)

# user_info와 성향이 비슷한 사람을 top_n만큼 추천
def find_similiar_user(user_info, df, top_n=10, first_del=False):
	start_n = 0
	if first_del == True:
		top_n = top_n + 1
		start_n = 1
	sim = euclidean_distance(user_info, df.iloc[:,6:])
	sim_sorted_idx = sim.argsort()
	sim_sorted_idx = sim_sorted_idx.reshape(-1).tolist()

	sim_sorted_id = df.iloc[sim_sorted_idx, 0]
	sim_sorted_id = sim_sorted_id.tolist()
	sim_sorted_id = sim_sorted_id[start_n:top_n]
	print("나의 BIG-FIVE 성향과 유사한 사람들 id : \n", sim_sorted_id)
	print("나의 BIG-FIVE 성향과 유사한 사람들 index : \n", sim_sorted_idx[start_n:top_n])
	return sim_sorted_id

# %%
# 가중치를 통한 영화 추천
def recommend_movie(user_info, df, movie, top_n=10, quantile=0.6):

	sim_sorted_id = find_similiar_user(user_info, df, top_n)

	reviewed_movie = set() # 중복을 제하기 위해 set()으로 객체생성

	for id in sim_sorted_id:
		reviewed_movie.update(movie[movie["userid"] == id].loc[:, "movie_id"].tolist())

	reviewed_movie = list(reviewed_movie)

	rating_df = pd.pivot_table(movie, index=["movie_id", "expected_name"], values=["rating"], aggfunc=["count", "mean"])
	rating_df.columns = ["count", "mean"]
	rating_df = rating_df.loc[reviewed_movie, :]

	C = np.mean(rating_df["mean"])
	m = rating_df["count"].quantile(quantile)
	print('C : {0}, m : {1}'.format(C, m))
	
	weight = []
	for i in range(len(rating_df)):
		v = rating_df.iloc[i]["count"]
		R = rating_df.iloc[i]["mean"]
		weight.append((v / (v + m)) * R + (m / (v + m)) * C)
	rating_df["weight"] = weight
	
	return rating_df.sort_values('weight', ascending=False)[:10] # 상위 10개의 영화만 리턴

# %%
from sklearn.preprocessing import MinMaxScaler

# start ~ end 사이의 값을 MinMaxScaler를 적용
def change_range(df, start, end):
	# MinMaxScaler
	pd.set_option("mode.chained_assignment", None)
	scaler = MinMaxScaler()
	train_array = np.arange(start, end).reshape(-1, 1)
	scaler.fit(train_array)
	tmp = scaler.transform(df["openness"].values.reshape(-1, 1))
	df["openness_scaler"] = tmp.reshape(-1)
	tmp = scaler.transform(df["agreeableness"].values.reshape(-1, 1))
	df["agreeableness_scaler"] = tmp.reshape(-1)
	tmp = scaler.transform(df["emotional_stability"].values.reshape(-1, 1))
	df["emotional_stability_scaler"] = tmp.reshape(-1)
	tmp = scaler.transform(df["conscientiousness"].values.reshape(-1, 1))
	df["conscientiousness_scaler"] = tmp.reshape(-1)
	tmp = scaler.transform(df["extraversion"].values.reshape(-1, 1))
	df["extraversion_scaler"] = tmp.reshape(-1)
	return df

# %% [markdown]
# #### 아이템 기반의 협업 필터링에서 개인화된 예측 평점
# $\hat{R_{u,i}} = \sum N(S_{i,N}*R_{u,N}) / \sum N(|S_{i,N}|)$
# - $\hat{R_{u,i}}$ : 사용자 u, 아이템 i의 개인화된 예측 평점 값
# - $S_{i,N}$ : 아이템 i와 가장 유사도가 높은 Top-N개 아이템의 유사도 벡터
# - $R_{u,N}$ : 사용자 u의 아이템 i와 가장 유사도가 높은 Top-N개 아이템에 대한 실제 평점 벡터

# %%
# 평점 예측
def predict_rating(ratings_arr, sim_arr):
	ratings_pred = ratings_arr.dot(sim_arr)/np.array([np.abs(sim_arr).sum(axis=1)])
	return ratings_pred

# %%
from sklearn.metrics import mean_squared_error
# mean_squared_error 
def get_mse(pred, real):
	pred = pred[real.nonzero()].flatten()
	real = real[real.nonzero()].flatten()
	return mean_squared_error(pred, real)

# %%
# 조금 더 정확성울 위해 평점 유사도에서 유사도가 높은 n개의 영화만 사용해서 평점을 예측
def predict_rating_topsim(ratings_arr, sim_arr, n=10):
	# 사용자-영화 평점 행렬 크기만큼 0으로 채운 예측 행렬
	pred = np.zeros(ratings_arr.shape)

	# 사용자-영화 평점 행렬의 열 크기만큼 루프 => 영화 개수만큼 루프
	for col in range(ratings_arr.shape[1]):
		# 유사도 행렬 (sim_arr)에서 유사도가 큰 순으로 n개 데이터
		top_n = [np.argsort(sim_arr[:, col])[:-n-1:-1]]
		# 평점 예측
		for row in range(ratings_arr.shape[0]):
			pred[row, col] = sim_arr[col, :][top_n].dot(ratings_arr[row, :][top_n].T)
			pred[row, col] /= np.sum(np.abs(sim_arr[col, :][top_n]))
	return pred

# %%
from sklearn.metrics.pairwise import cosine_similarity

# 영화 평점 간 유사도 측정
def search_ratings_sim(ratings):
	# 영화 간의 평점 유사도를 볼 것이기 때문에 전치행렬을 구해준다
	ratings_T = ratings.transpose()
	# 성격유형이 유사한 10명의 영화 평점을 기준으로 영화의 유사도를 생성
	rating_sim = cosine_similarity(ratings_T, ratings_T)
	rating_sim_df = pd.DataFrame(data=rating_sim, index=ratings_T.index, columns=ratings_T.index)
	return rating_sim_df

# %% [markdown]
# ---

# %%
import pandas as pd

personality = pd.read_csv("./data/2018-personality-data.csv")
personality.columns = personality.columns.str.strip()
personality_big5 = personality[['userid', 'openness', 'agreeableness', 'emotional_stability',
		'conscientiousness', 'extraversion']]
personality_big5.head()
# Out:
#                              userid  openness  agreeableness  \
# 0  8e7cebf9a234c064b75016249f2ac65e       5.0            2.0
# 1  77c7d756a093150d4377720abeaeef76       7.0            4.0
# 2  b7e8a92987a530cc368719a0e60e26a3       4.0            3.0
# 3  92561f21446e017dd6b68b94b23ad5b7       5.5            5.5
# 4  030001ac2145a938b07e686a35a2d638       5.5            5.5
#
#    emotional_stability  conscientiousness  extraversion
# 0                  3.0                2.5           6.5
# 1                  6.0                5.5           4.0
# 2                  4.5                2.0           2.5
# 3                  4.0                4.5           4.0
# 4                  3.5                4.5           2.5

# %%
ratings = pd.read_csv("./data/new_ratings.csv", index_col=0)
ratings.head()
# Out:
#                              userid  movie_id  rating                 tstamp  \
# 0  8e7cebf9a234c064b75016249f2ac65e         1     5.0   2001-09-10 17:19:56
# 1  8e7cebf9a234c064b75016249f2ac65e         2     4.0   2001-09-28 11:34:55
# 2  8e7cebf9a234c064b75016249f2ac65e         3     4.0   2001-09-28 11:42:50
# 3  8e7cebf9a234c064b75016249f2ac65e         5     5.0   2001-09-28 11:27:30
# 4  8e7cebf9a234c064b75016249f2ac65e         6     4.0   2002-01-07 18:12:02
#
#                         expected_name
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3  Father of the Bride Part II (1995)
# 4                         Heat (1995)

# %%
personality_big5 = change_range(personality_big5, 1, 8) # scaler
personality_big5.head()
# Out:
#                              userid  openness  agreeableness  \
# 0  8e7cebf9a234c064b75016249f2ac65e       5.0            2.0
# 1  77c7d756a093150d4377720abeaeef76       7.0            4.0
# 2  b7e8a92987a530cc368719a0e60e26a3       4.0            3.0
# 3  92561f21446e017dd6b68b94b23ad5b7       5.5            5.5
# 4  030001ac2145a938b07e686a35a2d638       5.5            5.5
#
#    emotional_stability  conscientiousness  extraversion  openness_scaler  \
# 0                  3.0                2.5           6.5         0.666667
# 1                  6.0                5.5           4.0         1.000000
# 2                  4.5                2.0           2.5         0.500000
# 3                  4.0                4.5           4.0         0.750000
# 4                  3.5                4.5           2.5         0.750000
#
#    agreeableness_scaler  emotional_stability_scaler  conscientiousness_scaler  \
# 0              0.166667                    0.333333                  0.250000
# 1              0.500000                    0.833333                  0.750000
# 2              0.333333                    0.583333                  0.166667
# 3              0.750000                    0.500000                  0.583333
# 4              0.750000                    0.416667                  0.583333
#
#    extraversion_scaler
# 0             0.916667
# 1             0.500000
# 2             0.250000
# 3             0.500000
# 4             0.250000

# %%
test_info = personality_big5.iloc[12:13, :] #12번째 데이터를 테스트용으로 사용
test_info
# Out:
#                               userid  openness  agreeableness  \
# 12  2507e0e5af7f4c6bef436c8cd0e90bc3       6.5            4.0
#
#     emotional_stability  conscientiousness  extraversion  openness_scaler  \
# 12                  2.5                6.0           4.0         0.916667
#
#     agreeableness_scaler  emotional_stability_scaler  \
# 12                   0.5                        0.25
#
#     conscientiousness_scaler  extraversion_scaler
# 12                  0.833333                  0.5

# %%
similiar_user = find_similiar_user(test_info.iloc[:, 6:], personality_big5, top_n=10, first_del=True)
similiar_user # 성격유형이 유사한 top_n명 찾기
# Out:
# 나의 BIG-FIVE 성향과 유사한 사람들 id :
#  ['3f77830c1b96c0ce003e248a069cf61d', '73b13da703becd9ab9903197cf246dee', '35afcbf0c50ede54759a40183469178c', 'ea4734eb95ee46f675d5768919930cc2', '1c1286bced458836d6c082753a70facc', '08419a2991116300be4f440f45f1c71e', '655e9ec8da090890d4301410f5b8dee5', '29269716223ac43f3921533adce28fce', '15ba0b093a9a409d176282ab8847047e', '192ff60bd8841ae6727ed1861e60156b']
# 나의 BIG-FIVE 성향과 유사한 사람들 index :
#  [97, 1726, 1625, 856, 718, 1518, 1505, 1525, 488, 1257]
# ['3f77830c1b96c0ce003e248a069cf61d',
#  '73b13da703becd9ab9903197cf246dee',
#  '35afcbf0c50ede54759a40183469178c',
#  'ea4734eb95ee46f675d5768919930cc2',
#  '1c1286bced458836d6c082753a70facc',
#  '08419a2991116300be4f440f45f1c71e',
#  '655e9ec8da090890d4301410f5b8dee5',
#  '29269716223ac43f3921533adce28fce',
#  '15ba0b093a9a409d176282ab8847047e',
#  '192ff60bd8841ae6727ed1861e60156b']

# %%
ratings = ratings.pivot_table('rating', index='userid', columns='expected_name')
ratings
# Out:
# expected_name                     '71 (2014)  \
# userid
# 005fe8678214011d7f92e51f9a546d40         NaN
# 0066fac81b62656f032c085d96e378f4         NaN
# 00fa91e202f5e48aa34c05d97867fa74         NaN
# 011aedbea90fb3b6d1e7a47526b3bee6         NaN
# 013325441cd1755b18c58b8007646bb1         NaN
# ...                                      ...
# feb85d3dbf8878d745c16a431bf6396e         NaN
# fefc161ac0b429fdbf6b56cc04dd4aa6         NaN
# ff14f409ad4f18cfcc72d2478355464d         NaN
# ff8b293ae258fe516c39acecb966dba4         NaN
# ffff31b8d1dd1486a7fe6914761aa655         NaN
#
# expected_name                     'Hellboy': The Seeds of Creation (2004)  \
# userid
# 005fe8678214011d7f92e51f9a546d40                                      NaN
# 0066fac81b62656f032c085d96e378f4                                      NaN
# 00fa91e202f5e48aa34c05d97867fa74                                      NaN
# 011aedbea90fb3b6d1e7a47526b3bee6                                      NaN
# 013325441cd1755b18c58b8007646bb1                                      NaN
# ...                                                                   ...
# feb85d3dbf8878d745c16a431bf6396e                                      NaN
# fefc161ac0b429fdbf6b56cc04dd4aa6                                      NaN
# ff14f409ad4f18cfcc72d2478355464d                                      NaN
# ff8b293ae258fe516c39acecb966dba4                                      NaN
# ffff31b8d1dd1486a7fe6914761aa655                                      NaN
#
# expected_name                     'Round Midnight (1986)  'Salem's Lot (2004)  \
# userid
# 005fe8678214011d7f92e51f9a546d40                     NaN                  NaN
# 0066fac81b62656f032c085d96e378f4                     NaN                  NaN
# 00fa91e202f5e48aa34c05d97867fa74                     NaN                  NaN
# 011aedbea90fb3b6d1e7a47526b3bee6                     NaN                  NaN
# 013325441cd1755b18c58b8007646bb1                     NaN                  NaN
# ...                                                  ...                  ...
# feb85d3dbf8878d745c16a431bf6396e                     NaN                  NaN
# fefc161ac0b429fdbf6b56cc04dd4aa6                     NaN                  NaN
# ff14f409ad4f18cfcc72d2478355464d                     NaN                  NaN
# ff8b293ae258fe516c39acecb966dba4                     NaN                  NaN
# ffff31b8d1dd1486a7fe6914761aa655                     NaN                  NaN
#
# expected_name                     'Til There Was You (1997)  \
# userid
# 005fe8678214011d7f92e51f9a546d40                        NaN
# 0066fac81b62656f032c085d96e378f4                        NaN
# 00fa91e202f5e48aa34c05d97867fa74                        NaN
# 011aedbea90fb3b6d1e7a47526b3bee6                        NaN
# 013325441cd1755b18c58b8007646bb1                        NaN
# ...                                                     ...
# feb85d3dbf8878d745c16a431bf6396e                        NaN
# fefc161ac0b429fdbf6b56cc04dd4aa6                        NaN
# ff14f409ad4f18cfcc72d2478355464d                        NaN
# ff8b293ae258fe516c39acecb966dba4                        NaN
# ffff31b8d1dd1486a7fe6914761aa655                        NaN
#
# expected_name                     'Tis the Season for Love (2015)  \
# userid
#
# expected_name                     À nous la liberté (Freedom for Us) (1931)
# userid
# 005fe8678214011d7f92e51f9a546d40                                        NaN
# 0066fac81b62656f032c085d96e378f4                                        NaN
# 00fa91e202f5e48aa34c05d97867fa74                                        NaN
# 011aedbea90fb3b6d1e7a47526b3bee6                                        NaN
# 013325441cd1755b18c58b8007646bb1                                        NaN
# ...                                                                     ...
# feb85d3dbf8878d745c16a431bf6396e                                        NaN
# fefc161ac0b429fdbf6b56cc04dd4aa6                                        NaN
# ff14f409ad4f18cfcc72d2478355464d                                        NaN
# ff8b293ae258fe516c39acecb966dba4                                        NaN
# ffff31b8d1dd1486a7fe6914761aa655                                        NaN
#
# [1820 rows x 9546 columns]

# %%
# 특정 사용자들의 영화 평점 리스트 유사도 찾기
similiar_ratings = ratings.loc[similiar_user] # 아까 구했던 성격 유형이 유사한 top_n명의 평점 데이터만 꺼내기
similiar_ratings = similiar_ratings.fillna(0)  # nan을 0으로 만들기
similiar_ratings
# Out:
# expected_name                     '71 (2014)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d         0.0
# 73b13da703becd9ab9903197cf246dee         0.0
# 35afcbf0c50ede54759a40183469178c         0.0
# ea4734eb95ee46f675d5768919930cc2         0.0
# 1c1286bced458836d6c082753a70facc         0.0
# 08419a2991116300be4f440f45f1c71e         0.0
# 655e9ec8da090890d4301410f5b8dee5         0.0
# 29269716223ac43f3921533adce28fce         0.0
# 15ba0b093a9a409d176282ab8847047e         0.0
# 192ff60bd8841ae6727ed1861e60156b         0.0
#
# expected_name                     'Hellboy': The Seeds of Creation (2004)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                                      0.0
# 73b13da703becd9ab9903197cf246dee                                      0.0
# 35afcbf0c50ede54759a40183469178c                                      0.0
# ea4734eb95ee46f675d5768919930cc2                                      0.0
# 1c1286bced458836d6c082753a70facc                                      0.0
# 08419a2991116300be4f440f45f1c71e                                      0.0
# 655e9ec8da090890d4301410f5b8dee5                                      0.0
# 29269716223ac43f3921533adce28fce                                      0.0
# 15ba0b093a9a409d176282ab8847047e                                      0.0
# 192ff60bd8841ae6727ed1861e60156b                                      0.0
#
# expected_name                     'Round Midnight (1986)  'Salem's Lot (2004)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                     0.0                  0.0
# 73b13da703becd9ab9903197cf246dee                     0.0                  0.0
# 35afcbf0c50ede54759a40183469178c                     0.0                  0.0
# ea4734eb95ee46f675d5768919930cc2                     0.0                  0.0
# 1c1286bced458836d6c082753a70facc                     0.0                  0.0
# 08419a2991116300be4f440f45f1c71e                     0.0                  0.0
# 655e9ec8da090890d4301410f5b8dee5                     0.0                  0.0
# 29269716223ac43f3921533adce28fce                     0.0                  0.0
# 15ba0b093a9a409d176282ab8847047e                     0.0                  0.0
# 192ff60bd8841ae6727ed1861e60156b                     0.0                  0.0
#
# expected_name                     'Til There Was You (1997)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                        0.0
# 73b13da703becd9ab9903197cf246dee                        0.0
# 35afcbf0c50ede54759a40183469178c                        0.0
# ea4734eb95ee46f675d5768919930cc2                        0.0
# 1c1286bced458836d6c082753a70facc                        0.0
# 08419a2991116300be4f440f45f1c71e                        0.0
# 655e9ec8da090890d4301410f5b8dee5                        0.0
# 29269716223ac43f3921533adce28fce                        0.0
# 15ba0b093a9a409d176282ab8847047e                        0.0
# 192ff60bd8841ae6727ed1861e60156b                        0.0
#
# expected_name                     'Tis the Season for Love (2015)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d
similiar_ratings_T.head()
# Out:
# userid                                   3f77830c1b96c0ce003e248a069cf61d  \
# expected_name
# '71 (2014)                                                            0.0
# 'Hellboy': The Seeds of Creation (2004)                               0.0
# 'Round Midnight (1986)                                                0.0
# 'Salem's Lot (2004)                                                   0.0
# 'Til There Was You (1997)                                             0.0
#
# userid                                   73b13da703becd9ab9903197cf246dee  \
# expected_name
# '71 (2014)                                                            0.0
# 'Hellboy': The Seeds of Creation (2004)                               0.0
# 'Round Midnight (1986)                                                0.0
# 'Salem's Lot (2004)                                                   0.0
# 'Til There Was You (1997)                                             0.0
#
# userid                                   35afcbf0c50ede54759a40183469178c  \
# expected_name
# '71 (2014)                                                            0.0
# 'Hellboy': The Seeds of Creation (2004)                               0.0
# 'Round Midnight (1986)                                                0.0
# 'Salem's Lot (2004)                                                   0.0
# 'Til There Was You (1997)                                             0.0
#
# userid                                   ea4734eb95ee46f675d5768919930cc2  \
# expected_name
# '71 (2014)                                                            0.0
# 'Hellboy': The Seeds of Creation (2004)                               0.0
# 'Round Midnight (1986)                                                0.0
# 'Salem's Lot (2004)                                                   0.0
# 'Til There Was You (1997)                                             0.0
#
# userid                                   1c1286bced458836d6c082753a70facc  \
# expected_name
# '71 (2014)                                                            0.0
# 'Hellboy': The Seeds of Creation (2004)                               0.0
# 'Round Midnight (1986)                                                0.0
# 'Salem's Lot (2004)                                                   0.0
# 'Til There Was You (1997)                                             0.0
#
# userid                                   08419a2991116300be4f440f45f1c71e  \
# expected_name
# '71 (2014)                                                            0.0
# 'Hellboy': The Seeds of Creation (2004)                               0.0
# 'Round Midnight (1986)                                                0.0
# 'Salem's Lot (2004)                                                   0.0
# 'Til There Was You (1997)                                             0.0
#
# userid                                   655e9ec8da090890d4301410f5b8dee5  \
# expected_name
# '71 (2014)                                                            0.0
# 'Hellboy': The Seeds of Creation (2004)                               0.0
# 'Round Midnight (1986)                                                0.0
# 'Salem's Lot (2004)                                                   0.0
# 'Til There Was You (1997)                                             0.0
#
# userid                                   29269716223ac43f3921533adce28fce  \
# expected_name
# '71 (2014)                                                            0.0
# 'Hellboy': The Seeds of Creation (2004)                               0.0
# 'Round Midnight (1986)                                                0.0
# 'Salem's Lot (2004)                                                   0.0
# 'Til There Was You (1997)                                             0.0
#
# userid                                   15ba0b093a9a409d176282ab8847047e  \
# expected_name
# '71 (2014)                                                            0.0
# 'Hellboy': The Seeds of Creation (2004)                               0.0
# 'Round Midnight (1986)                                                0.0
# 'Salem's Lot (2004)                                                   0.0
# 'Til There Was You (1997)                                             0.0
#
# userid                                   192ff60bd8841ae6727ed1861e60156b
# expected_name
# '71 (2014)                                                            0.0
# 'Hellboy': The Seeds of Creation (2004)                               0.0
# 'Round Midnight (1986)                                                0.0
# 'Salem's Lot (2004)                                                   0.0
# 'Til There Was You (1997)                                             0.0

# %%
from sklearn.metrics.pairwise import cosine_similarity

rating_sim = cosine_similarity(similiar_ratings_T, similiar_ratings_T)
rating_sim_df = pd.DataFrame(data=rating_sim, index=similiar_ratings.columns, columns=similiar_ratings.columns)
rating_sim_df # 성격유형이 유사한 10명의 영화 평점들간 유사도
# Out:
# expected_name                              '71 (2014)  \
# expected_name
# '71 (2014)                                        0.0
# 'Hellboy': The Seeds of Creation (2004)           0.0
# 'Round Midnight (1986)                            0.0
# 'Salem's Lot (2004)                               0.0
# 'Til There Was You (1997)                         0.0
# ...                                               ...
# eXistenZ (1999)                                   0.0
# xXx (2002)                                        0.0
# xXx: State of the Union (2005)                    0.0
# ¡Three Amigos! (1986)                             0.0
# À nous la liberté (Freedom for Us) (1931)         0.0
#
# expected_name                              'Hellboy': The Seeds of Creation (2004)  \
# expected_name
# '71 (2014)                                                                     0.0
# 'Hellboy': The Seeds of Creation (2004)                                        0.0
# 'Round Midnight (1986)                                                         0.0
# 'Salem's Lot (2004)                                                            0.0
# 'Til There Was You (1997)                                                      0.0
# ...                                                                            ...
# eXistenZ (1999)                                                                0.0
# xXx (2002)                                                                     0.0
# xXx: State of the Union (2005)                                                 0.0
# ¡Three Amigos! (1986)                                                          0.0
# À nous la liberté (Freedom for Us) (1931)                                      0.0
#
# expected_name                              'Round Midnight (1986)  \
# expected_name
# '71 (2014)                                                    0.0
# 'Hellboy': The Seeds of Creation (2004)                       0.0
# 'Round Midnight (1986)                                        0.0
# 'Salem's Lot (2004)                                           0.0
# 'Til There Was You (1997)                                     0.0
# ...                                                           ...
# eXistenZ (1999)                                               0.0
# xXx (2002)                                                    0.0
# xXx: State of the Union (2005)                                0.0
# ¡Three Amigos! (1986)                                         0.0
# À nous la liberté (Freedom for Us) (1931)                     0.0
#
# expected_name                              'Salem's Lot (2004)  \
# expected_name
# '71 (2014)                                                 0.0
# 'Hellboy': The Seeds of Creation (2004)                    0.0
# 'Round Midnight (1986)                                     0.0
# 'Salem's Lot (2004)                                        0.0
# 'Til There Was You (1997)                                  0.0
# ...                                                        ...
# eXistenZ (1999)                                            0.0
# xXx (2002)                                                 0.0
# xXx: State of the Union (2005)                             0.0
# ¡Three Amigos! (1986)                                      0.0
# À nous la liberté (Freedom for Us) (1931)                  0.0
#
# expected_name                              'Til There Was You (1997)  \
# expected_name
# '71 (2014)                                                       0.0
# 'Hellboy': The Seeds of Creation (2004)                          0.0
# 'Round Midnight (1986)                                           0.0
# 'Salem's Lot (2004)                                              0.0
# 'Til There Was You (1997)                                        0.0
# ...                                                              ...
# eXistenZ (1999)                                                  0.0
# xXx (2002)                                                       0.0
# xXx: State of the Union (2005)                                   0.0
# ¡Three Amigos! (1986)                                            0.0
# À nous la liberté (Freedom for Us) (1931)                        0.0
#
# expected_name                              'Tis the Season for Love (2015)  \
# expected_name
# '71 (2014)                                                             0.0
# 'Hellboy': The Seeds of Creation (2004)                                0.0
# 'Round Midnight (1986)                                                 0.0
# 'Salem's Lot (2004)                                                    0.0
# 'Til There Was You (1997)                                              0.0
# ...                                                                    ...
# eXistenZ (1999)                                                        0.0
# xXx (2002)                                                             0.0
# xXx: State of the Union (2005)                                         0.0
# ¡Three Amigos! (1986)                                                  0.0
# À nous la liberté (Freedom for Us) (1931)                              0.0
#
# expected_name                              'burbs, The (1989)  \
# expected_name
# '71 (2014)                                                0.0
# 'Hellboy': The Seeds of Creation (2004)                   0.0
# 'Round Midnight (1986)                                    0.0
# 'Salem's Lot (2004)                                       0.0
# 'Til There Was You (1997)                                 0.0
# ...                                                       ...
# eXistenZ (1999)                                           0.0
# xXx (2002)                                                0.0
# xXx: State of the Union (2005)                            0.0
# ¡Three Amigos! (1986)                                     0.0
# À nous la liberté (Freedom for Us) (1931)                 0.0
#
# expected_name                              'night Mother (1986)  \
# expected_name
# '71 (2014)                                                  0.0
# 'Hellboy': The Seeds of Creation (2004)                     0.0
# 'Round Midnight (1986)                                      0.0
# 'Salem's Lot (2004)                                         0.0
# 'Til There Was You (1997)                                   0.0
# ...                                                         ...
# eXistenZ (1999)                                             0.0
# xXx (2002)                                                  0.0
# xXx: State of the Union (2005)                              0.0
# ¡Three Amigos! (1986)                                       0.0
# À nous la liberté (Freedom for Us) (1931)                   0.0
#
# expected_name                              (500) Days of Summer (2009)  \
# expected_name
# '71 (2014)                                                        0.00
# 'Hellboy': The Seeds of Creation (2004)                           0.00
# 'Round Midnight (1986)                                            0.00
# 'Salem's Lot (2004)                                               0.00
# 'Til There Was You (1997)                                         0.00
# ...                                                                ...
# eXistenZ (1999)                                                   0.00
# xXx (2002)                                                        0.64
# xXx: State of the Union (2005)                                    0.00
# ¡Three Amigos! (1986)                                             0.00
# À nous la liberté (Freedom for Us) (1931)                         0.00
#
# expected_name                              *batteries not included (1987)  \
# expected_name
# '71 (2014)                                                            0.0
# 'Hellboy': The Seeds of Creation (2004)                               0.0
# 'Round Midnight (1986)                                                0.0
# 'Salem's Lot (2004)                                                   0.0
# 'Til There Was You (1997)                                             0.0
# ...                                                                   ...
# eXistenZ (1999)                                                       0.0
# xXx (2002)                                                            0.0
# xXx: State of the Union (2005)                                        0.0
# ¡Three Amigos! (1986)                                                 0.0
# À nous la liberté (Freedom for Us) (1931)                             0.0
#
# expected_name                              ...  Zulu (1964)  Zulu (2013)  \
# expected_name                              ...
# '71 (2014)                                 ...          0.0          0.0
# 'Hellboy': The Seeds of Creation (2004)    ...          0.0          0.0
# 'Round Midnight (1986)                     ...          0.0          0.0
# 'Salem's Lot (2004)                        ...          0.0          0.0
# 'Til There Was You (1997)                  ...          0.0          0.0
# ...                                        ...          ...          ...
# eXistenZ (1999)                            ...          0.0          0.0
# xXx (2002)                                 ...          0.0          0.0
# xXx: State of the Union (2005)             ...          0.0          0.0
# ¡Three Amigos! (1986)                      ...          0.0          0.0
# À nous la liberté (Freedom for Us) (1931)  ...          0.0          0.0
#
# expected_name                              [REC] (2007)  [REC]² (2009)  \
# expected_name
# '71 (2014)                                          0.0            0.0
# 'Hellboy': The Seeds of Creation (2004)             0.0            0.0
# 'Round Midnight (1986)                              0.0            0.0
# 'Salem's Lot (2004)                                 0.0            0.0
# 'Til There Was You (1997)                           0.0            0.0
# ...                                                 ...            ...
# eXistenZ (1999)                                     0.0            0.0
# xXx (2002)                                          0.0            0.0
# xXx: State of the Union (2005)                      0.0            0.0
# ¡Three Amigos! (1986)                               0.0            0.0
# À nous la liberté (Freedom for Us) (1931)           0.0            0.0
#
# expected_name                              [REC]³ 3 Génesis (2012)  \
# expected_name
# '71 (2014)                                                     0.0
# 'Hellboy': The Seeds of Creation (2004)                        0.0
# 'Round Midnight (1986)                                         0.0
# 'Salem's Lot (2004)                                            0.0
# 'Til There Was You (1997)                                      0.0
# ...                                                            ...
# eXistenZ (1999)                                                0.0
# xXx (2002)                                                     0.0
# xXx: State of the Union (2005)                                 0.0
# ¡Three Amigos! (1986)                                          0.0
# À nous la liberté (Freedom for Us) (1931)                      0.0
#
# expected_name                              eXistenZ (1999)  xXx (2002)  \
# expected_name
# '71 (2014)                                             0.0         0.0
# 'Hellboy': The Seeds of Creation (2004)                0.0         0.0
# 'Round Midnight (1986)                                 0.0         0.0
# 'Salem's Lot (2004)                                    0.0         0.0
# 'Til There Was You (1997)                              0.0         0.0
# ...                                                    ...         ...
# eXistenZ (1999)                                        0.0         0.0
# xXx (2002)                                             0.0         1.0
# xXx: State of the Union (2005)                         0.0         0.0
# ¡Three Amigos! (1986)                                  0.0         0.0
# À nous la liberté (Freedom for Us) (1931)              0.0         0.0
#
# expected_name                              xXx: State of the Union (2005)  \
# expected_name
# '71 (2014)                                                            0.0
# 'Hellboy': The Seeds of Creation (2004)                               0.0
# 'Round Midnight (1986)                                                0.0
# 'Salem's Lot (2004)                                                   0.0
# 'Til There Was You (1997)                                             0.0
# ...                                                                   ...
# eXistenZ (1999)                                                       0.0
# xXx (2002)                                                            0.0
# xXx: State of the Union (2005)                                        0.0
# ¡Three Amigos! (1986)                                                 0.0
# À nous la liberté (Freedom for Us) (1931)                             0.0
#
# expected_name                              ¡Three Amigos! (1986)  \
# expected_name
# '71 (2014)                                                   0.0
# 'Hellboy': The Seeds of Creation (2004)                      0.0
# 'Round Midnight (1986)                                       0.0
# 'Salem's Lot (2004)                                          0.0
# 'Til There Was You (1997)                                    0.0
# ...                                                          ...
# eXistenZ (1999)                                              0.0
# xXx (2002)                                                   0.0
# xXx: State of the Union (2005)                               0.0
# ¡Three Amigos! (1986)                                        0.0
# À nous la liberté (Freedom for Us) (1931)                    0.0
#
# expected_name                              À nous la liberté (Freedom for Us) (1931)
# expected_name
# '71 (2014)                                                                       0.0
# 'Hellboy': The Seeds of Creation (2004)                                          0.0
# 'Round Midnight (1986)                                                           0.0
# 'Salem's Lot (2004)                                                              0.0
# 'Til There Was You (1997)                                                        0.0
# ...                                                                              ...
# eXistenZ (1999)                                                                  0.0
# xXx (2002)                                                                       0.0
# xXx: State of the Union (2005)                                                   0.0
# ¡Three Amigos! (1986)                                                            0.0
# À nous la liberté (Freedom for Us) (1931)                                        0.0
#
# [9546 rows x 9546 columns]

# %%
ratings_pred = predict_rating(similiar_ratings.values, rating_sim_df.values) # 평점 예측
ratings_pred_df = pd.DataFrame(data=ratings_pred, index=similiar_ratings.index, columns=similiar_ratings.columns)
ratings_pred_df.head()
# Out:
# /var/folders/11/1m6f75m12njbgxh3vk632bp00000gn/T/ipykernel_3493/2850991744.py:3: RuntimeWarning: invalid value encountered in true_divide
#   ratings_pred = ratings_arr.dot(sim_arr)/np.array([np.abs(sim_arr).sum(axis=1)])
# expected_name                     '71 (2014)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d         NaN
# 73b13da703becd9ab9903197cf246dee         NaN
# 35afcbf0c50ede54759a40183469178c         NaN
# ea4734eb95ee46f675d5768919930cc2         NaN
# 1c1286bced458836d6c082753a70facc         NaN
#
# expected_name                     'Hellboy': The Seeds of Creation (2004)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                                      NaN
# 73b13da703becd9ab9903197cf246dee                                      NaN
# 35afcbf0c50ede54759a40183469178c                                      NaN
# ea4734eb95ee46f675d5768919930cc2                                      NaN
# 1c1286bced458836d6c082753a70facc                                      NaN
#
# expected_name                     'Round Midnight (1986)  'Salem's Lot (2004)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                     NaN                  NaN
# 73b13da703becd9ab9903197cf246dee                     NaN                  NaN
# 35afcbf0c50ede54759a40183469178c                     NaN                  NaN
# ea4734eb95ee46f675d5768919930cc2                     NaN                  NaN
# 1c1286bced458836d6c082753a70facc                     NaN                  NaN
#
# expected_name                     'Til There Was You (1997)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                        NaN
# 73b13da703becd9ab9903197cf246dee                        NaN
# 35afcbf0c50ede54759a40183469178c                        NaN
# ea4734eb95ee46f675d5768919930cc2                        NaN
# 1c1286bced458836d6c082753a70facc                        NaN
#
# expected_name                     'Tis the Season for Love (2015)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                              NaN
# 73b13da703becd9ab9903197cf246dee                              NaN
# 35afcbf0c50ede54759a40183469178c                              NaN
# ea4734eb95ee46f675d5768919930cc2                              NaN
# 1c1286bced458836d6c082753a70facc                              NaN
#
# expected_name                     'burbs, The (1989)  'night Mother (1986)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                 NaN                   NaN
# 73b13da703becd9ab9903197cf246dee                 NaN                   NaN
# 35afcbf0c50ede54759a40183469178c                 NaN                   NaN
# ea4734eb95ee46f675d5768919930cc2                 NaN                   NaN
# 1c1286bced458836d6c082753a70facc                 NaN                   NaN
#
# expected_name                     (500) Days of Summer (2009)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                     0.359634
# 73b13da703becd9ab9903197cf246dee                     0.193712
# 35afcbf0c50ede54759a40183469178c                     0.288722
# ea4734eb95ee46f675d5768919930cc2                     0.972428
# 1c1286bced458836d6c082753a70facc                     0.366417
#
# expected_name                     *batteries not included (1987)  ...  \
# userid                                                            ...
# 3f77830c1b96c0ce003e248a069cf61d                             NaN  ...
# 73b13da703becd9ab9903197cf246dee                             NaN  ...
# 35afcbf0c50ede54759a40183469178c                             NaN  ...
# ea4734eb95ee46f675d5768919930cc2                             NaN  ...
# 1c1286bced458836d6c082753a70facc                             NaN  ...
#
# expected_name                     Zulu (1964)  Zulu (2013)  [REC] (2007)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d          NaN          NaN           NaN
# 73b13da703becd9ab9903197cf246dee          NaN          NaN           NaN
# 35afcbf0c50ede54759a40183469178c          NaN          NaN           NaN
# ea4734eb95ee46f675d5768919930cc2          NaN          NaN           NaN
# 1c1286bced458836d6c082753a70facc          NaN          NaN           NaN
#
# expected_name                     [REC]² (2009)  [REC]³ 3 Génesis (2012)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d            NaN                      NaN
# 73b13da703becd9ab9903197cf246dee            NaN                      NaN
# 35afcbf0c50ede54759a40183469178c            NaN                      NaN
# ea4734eb95ee46f675d5768919930cc2            NaN                      NaN
# 1c1286bced458836d6c082753a70facc            NaN                      NaN
#
# expected_name                     eXistenZ (1999)  xXx (2002)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d              NaN    0.311399
# 73b13da703becd9ab9903197cf246dee              NaN    0.186948
# 35afcbf0c50ede54759a40183469178c              NaN    0.267646
# ea4734eb95ee46f675d5768919930cc2              NaN    1.861385
# 1c1286bced458836d6c082753a70facc              NaN    0.320818
#
# expected_name                     xXx: State of the Union (2005)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                             NaN
# 73b13da703becd9ab9903197cf246dee                             NaN
# 35afcbf0c50ede54759a40183469178c                             NaN
# ea4734eb95ee46f675d5768919930cc2                             NaN
# 1c1286bced458836d6c082753a70facc                             NaN
#
# expected_name                     ¡Three Amigos! (1986)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                    NaN
# 73b13da703becd9ab9903197cf246dee                    NaN
# 35afcbf0c50ede54759a40183469178c                    NaN
# ea4734eb95ee46f675d5768919930cc2                    NaN
# 1c1286bced458836d6c082753a70facc                    NaN
#
# expected_name                     À nous la liberté (Freedom for Us) (1931)
# userid
# 3f77830c1b96c0ce003e248a069cf61d                                        NaN
# 73b13da703becd9ab9903197cf246dee                                        NaN
# 35afcbf0c50ede54759a40183469178c                                        NaN
# ea4734eb95ee46f675d5768919930cc2                                        NaN
# 1c1286bced458836d6c082753a70facc                                        NaN
#
# [5 rows x 9546 columns]

# %%
print("아이템 기반 모든 최근접 이웃 MSE : ", get_mse(ratings_pred, similiar_ratings.values))
# Out:
# 아이템 기반 모든 최근접 이웃 MSE :  4.1649630648576625

# %% [markdown]
# ---

# %%
# 조금 더 확실하게 하기 위해서 유사도가 높은 10개의 영화만 가지고 평점 예측
ratings_pred_2 = predict_rating_topsim(similiar_ratings.values, rating_sim_df.values)
ratings_pred_2_df = pd.DataFrame(data=ratings_pred_2, index=similiar_ratings.index, columns=similiar_ratings.columns)
ratings_pred_2_df.head()
# Out:
# /var/folders/11/1m6f75m12njbgxh3vk632bp00000gn/T/ipykernel_3493/1516217411.py:12: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   pred[row, col] = sim_arr[col, :][top_n].dot(ratings_arr[row, :][top_n].T)
# /var/folders/11/1m6f75m12njbgxh3vk632bp00000gn/T/ipykernel_3493/1516217411.py:13: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   pred[row, col] /= np.sum(np.abs(sim_arr[col, :][top_n]))
# /var/folders/11/1m6f75m12njbgxh3vk632bp00000gn/T/ipykernel_3493/1516217411.py:13: RuntimeWarning: invalid value encountered in double_scalars
#   pred[row, col] /= np.sum(np.abs(sim_arr[col, :][top_n]))
# expected_name                     '71 (2014)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d         NaN
# 73b13da703becd9ab9903197cf246dee         NaN
# 35afcbf0c50ede54759a40183469178c         NaN
# ea4734eb95ee46f675d5768919930cc2         NaN
# 1c1286bced458836d6c082753a70facc         NaN
#
# expected_name                     'Hellboy': The Seeds of Creation (2004)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                                      NaN
# 73b13da703becd9ab9903197cf246dee                                      NaN
# 35afcbf0c50ede54759a40183469178c                                      NaN
# ea4734eb95ee46f675d5768919930cc2                                      NaN
# 1c1286bced458836d6c082753a70facc                                      NaN
#
# expected_name                     'Round Midnight (1986)  'Salem's Lot (2004)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                     NaN                  NaN
# 73b13da703becd9ab9903197cf246dee                     NaN                  NaN
# 35afcbf0c50ede54759a40183469178c                     NaN                  NaN
# ea4734eb95ee46f675d5768919930cc2                     NaN                  NaN
# 1c1286bced458836d6c082753a70facc                     NaN                  NaN
#
# expected_name                     'Til There Was You (1997)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                        NaN
# 73b13da703becd9ab9903197cf246dee                        NaN
# 35afcbf0c50ede54759a40183469178c                        NaN
# ea4734eb95ee46f675d5768919930cc2                        NaN
# 1c1286bced458836d6c082753a70facc                        NaN
#
# expected_name                     'Tis the Season for Love (2015)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                              NaN
# 73b13da703becd9ab9903197cf246dee                              NaN
# 35afcbf0c50ede54759a40183469178c                              NaN
# ea4734eb95ee46f675d5768919930cc2                              NaN
# 1c1286bced458836d6c082753a70facc                              NaN
#
# expected_name                     'burbs, The (1989)  'night Mother (1986)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                 NaN                   NaN
# 73b13da703becd9ab9903197cf246dee                 NaN                   NaN
# 35afcbf0c50ede54759a40183469178c                 NaN                   NaN
# ea4734eb95ee46f675d5768919930cc2                 NaN                   NaN
# 1c1286bced458836d6c082753a70facc                 NaN                   NaN
#
# expected_name                     (500) Days of Summer (2009)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                          0.0
# 73b13da703becd9ab9903197cf246dee                          0.0
# 35afcbf0c50ede54759a40183469178c                          0.0
# ea4734eb95ee46f675d5768919930cc2                          0.0
# 1c1286bced458836d6c082753a70facc                          0.0
#
# expected_name                     *batteries not included (1987)  ...  \
# userid                                                            ...
# 3f77830c1b96c0ce003e248a069cf61d                             NaN  ...
# 73b13da703becd9ab9903197cf246dee                             NaN  ...
# 35afcbf0c50ede54759a40183469178c                             NaN  ...
# ea4734eb95ee46f675d5768919930cc2                             NaN  ...
# 1c1286bced458836d6c082753a70facc                             NaN  ...
#
# expected_name                     Zulu (1964)  Zulu (2013)  [REC] (2007)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d          NaN          NaN           NaN
# 73b13da703becd9ab9903197cf246dee          NaN          NaN           NaN
# 35afcbf0c50ede54759a40183469178c          NaN          NaN           NaN
# ea4734eb95ee46f675d5768919930cc2          NaN          NaN           NaN
# 1c1286bced458836d6c082753a70facc          NaN          NaN           NaN
#
# expected_name                     [REC]² (2009)  [REC]³ 3 Génesis (2012)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d            NaN                      NaN
# 73b13da703becd9ab9903197cf246dee            NaN                      NaN
# 35afcbf0c50ede54759a40183469178c            NaN                      NaN
# ea4734eb95ee46f675d5768919930cc2            NaN                      NaN
# 1c1286bced458836d6c082753a70facc            NaN                      NaN
#
# expected_name                     eXistenZ (1999)  xXx (2002)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d              NaN     0.00000
# 73b13da703becd9ab9903197cf246dee              NaN     0.00000
# 35afcbf0c50ede54759a40183469178c              NaN     0.00000
# ea4734eb95ee46f675d5768919930cc2              NaN     2.14982
# 1c1286bced458836d6c082753a70facc              NaN     0.00000
#
# expected_name                     xXx: State of the Union (2005)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                             NaN
# 73b13da703becd9ab9903197cf246dee                             NaN
# 35afcbf0c50ede54759a40183469178c                             NaN
# ea4734eb95ee46f675d5768919930cc2                             NaN
# 1c1286bced458836d6c082753a70facc                             NaN
#
# expected_name                     ¡Three Amigos! (1986)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                    NaN
# 73b13da703becd9ab9903197cf246dee                    NaN
# 35afcbf0c50ede54759a40183469178c                    NaN
# ea4734eb95ee46f675d5768919930cc2                    NaN
# 1c1286bced458836d6c082753a70facc                    NaN
#
# expected_name                     À nous la liberté (Freedom for Us) (1931)
# userid
# 3f77830c1b96c0ce003e248a069cf61d                                        NaN
# 73b13da703becd9ab9903197cf246dee                                        NaN
# 35afcbf0c50ede54759a40183469178c                                        NaN
# ea4734eb95ee46f675d5768919930cc2                                        NaN
# 1c1286bced458836d6c082753a70facc                                        NaN
#
# [5 rows x 9546 columns]

# %%
print("아이템 기반 모든 최근접 이웃 MSE : ", get_mse(ratings_pred_2, similiar_ratings.values))
# Out:
# 아이템 기반 모든 최근접 이웃 MSE :  0.6857309498965477

# %%
ratings_pred_2_df
# Out:
# expected_name                     '71 (2014)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d         NaN
# 73b13da703becd9ab9903197cf246dee         NaN
# 35afcbf0c50ede54759a40183469178c         NaN
# ea4734eb95ee46f675d5768919930cc2         NaN
# 1c1286bced458836d6c082753a70facc         NaN
# 08419a2991116300be4f440f45f1c71e         NaN
# 655e9ec8da090890d4301410f5b8dee5         NaN
# 29269716223ac43f3921533adce28fce         NaN
# 15ba0b093a9a409d176282ab8847047e         NaN
# 192ff60bd8841ae6727ed1861e60156b         NaN
#
# expected_name                     'Hellboy': The Seeds of Creation (2004)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                                      NaN
# 73b13da703becd9ab9903197cf246dee                                      NaN
# 35afcbf0c50ede54759a40183469178c                                      NaN
# ea4734eb95ee46f675d5768919930cc2                                      NaN
# 1c1286bced458836d6c082753a70facc                                      NaN
# 08419a2991116300be4f440f45f1c71e                                      NaN
# 655e9ec8da090890d4301410f5b8dee5                                      NaN
# 29269716223ac43f3921533adce28fce                                      NaN
# 15ba0b093a9a409d176282ab8847047e                                      NaN
# 192ff60bd8841ae6727ed1861e60156b                                      NaN
#
# expected_name                     'Round Midnight (1986)  'Salem's Lot (2004)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                     NaN                  NaN
# 73b13da703becd9ab9903197cf246dee                     NaN                  NaN
# 35afcbf0c50ede54759a40183469178c                     NaN                  NaN
# ea4734eb95ee46f675d5768919930cc2                     NaN                  NaN
# 1c1286bced458836d6c082753a70facc                     NaN                  NaN
# 08419a2991116300be4f440f45f1c71e                     NaN                  NaN
# 655e9ec8da090890d4301410f5b8dee5                     NaN                  NaN
# 29269716223ac43f3921533adce28fce                     NaN                  NaN
# 15ba0b093a9a409d176282ab8847047e                     NaN                  NaN
# 192ff60bd8841ae6727ed1861e60156b                     NaN                  NaN
#
# expected_name                     'Til There Was You (1997)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                        NaN
# 73b13da703becd9ab9903197cf246dee                        NaN
# 35afcbf0c50ede54759a40183469178c                        NaN
# ea4734eb95ee46f675d5768919930cc2                        NaN
# 1c1286bced458836d6c082753a70facc                        NaN
# 08419a2991116300be4f440f45f1c71e                        NaN
# 655e9ec8da090890d4301410f5b8dee5                        NaN
# 29269716223ac43f3921533adce28fce                        NaN
# 15ba0b093a9a409d176282ab8847047e                        NaN
# 192ff60bd8841ae6727ed1861e60156b                        NaN
#
# expected_name                     'Tis the Season for Love (2015)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                              NaN
# 73b13da703becd9ab9903197cf246dee                              NaN
# 35afcbf0c50ede54759a40183469178c                              NaN
# ea4734eb95ee46f675d5768919930cc2                              NaN
# 1c1286bced458836d6c082753a70facc                              NaN
# 08419a2991116300be4f440f45f1c71e                              NaN
# 655e9ec8da090890d4301410f5b8dee5                              NaN
# 29269716223ac43f3921533adce28fce                              NaN
# 15ba0b093a9a409d176282ab8847047e                              NaN
# 192ff60bd8841ae6727ed1861e60156b                              NaN
#
# expected_name                     'burbs, The (1989)  'night Mother (1986)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                 NaN                   NaN
# 73b13da703becd9ab9903197cf246dee                 NaN                   NaN
# 35afcbf0c50ede54759a40183469178c                 NaN                   NaN
# ea4734eb95ee46f675d5768919930cc2                 NaN                   NaN
# 1c1286bced458836d6c082753a70facc                 NaN                   NaN
# 08419a2991116300be4f440f45f1c71e                 NaN                   NaN
# 655e9ec8da090890d4301410f5b8dee5                 NaN                   NaN
# 29269716223ac43f3921533adce28fce                 NaN                   NaN
# 15ba0b093a9a409d176282ab8847047e                 NaN                   NaN
# 192ff60bd8841ae6727ed1861e60156b                 NaN                   NaN
#
# expected_name                     (500) Days of Summer (2009)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                     0.000000
# 73b13da703becd9ab9903197cf246dee                     0.000000
# 35afcbf0c50ede54759a40183469178c                     0.000000
# ea4734eb95ee46f675d5768919930cc2                     0.000000
# 1c1286bced458836d6c082753a70facc                     0.000000
# 08419a2991116300be4f440f45f1c71e                     0.000000
# 655e9ec8da090890d4301410f5b8dee5                     2.600069
# 29269716223ac43f3921533adce28fce                     0.000000
# 15ba0b093a9a409d176282ab8847047e                     3.500098
# 192ff60bd8841ae6727ed1861e60156b                     0.000000
#
# expected_name                     *batteries not included (1987)  ...  \
# userid                                                            ...
# 3f77830c1b96c0ce003e248a069cf61d                             NaN  ...
# 73b13da703becd9ab9903197cf246dee                             NaN  ...
# 35afcbf0c50ede54759a40183469178c                             NaN  ...
# ea4734eb95ee46f675d5768919930cc2                             NaN  ...
# 1c1286bced458836d6c082753a70facc                             NaN  ...
# 08419a2991116300be4f440f45f1c71e                             NaN  ...
# 655e9ec8da090890d4301410f5b8dee5                             NaN  ...
# 29269716223ac43f3921533adce28fce                             NaN  ...
# 15ba0b093a9a409d176282ab8847047e                             NaN  ...
# 192ff60bd8841ae6727ed1861e60156b                             NaN  ...
#
# expected_name                     Zulu (1964)  Zulu (2013)  [REC] (2007)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d          NaN          NaN           NaN
# 73b13da703becd9ab9903197cf246dee          NaN          NaN           NaN
# 35afcbf0c50ede54759a40183469178c          NaN          NaN           NaN
# ea4734eb95ee46f675d5768919930cc2          NaN          NaN           NaN
# 1c1286bced458836d6c082753a70facc          NaN          NaN           NaN
# 08419a2991116300be4f440f45f1c71e          NaN          NaN           NaN
# 655e9ec8da090890d4301410f5b8dee5          NaN          NaN           NaN
# 29269716223ac43f3921533adce28fce          NaN          NaN           NaN
# 15ba0b093a9a409d176282ab8847047e          NaN          NaN           NaN
# 192ff60bd8841ae6727ed1861e60156b          NaN          NaN           NaN
#
# expected_name                     [REC]² (2009)  [REC]³ 3 Génesis (2012)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d            NaN                      NaN
# 73b13da703becd9ab9903197cf246dee            NaN                      NaN
# 35afcbf0c50ede54759a40183469178c            NaN                      NaN
# ea4734eb95ee46f675d5768919930cc2            NaN                      NaN
# 1c1286bced458836d6c082753a70facc            NaN                      NaN
# 08419a2991116300be4f440f45f1c71e            NaN                      NaN
# 655e9ec8da090890d4301410f5b8dee5            NaN                      NaN
# 29269716223ac43f3921533adce28fce            NaN                      NaN
# 15ba0b093a9a409d176282ab8847047e            NaN                      NaN
# 192ff60bd8841ae6727ed1861e60156b            NaN                      NaN
#
# expected_name                     eXistenZ (1999)  xXx (2002)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d              NaN    0.000000
# 73b13da703becd9ab9903197cf246dee              NaN    0.000000
# 35afcbf0c50ede54759a40183469178c              NaN    0.000000
# ea4734eb95ee46f675d5768919930cc2              NaN    2.149820
# 1c1286bced458836d6c082753a70facc              NaN    0.000000
# 08419a2991116300be4f440f45f1c71e              NaN    0.000000
# 655e9ec8da090890d4301410f5b8dee5              NaN    0.000000
# 29269716223ac43f3921533adce28fce              NaN    0.000000
# 15ba0b093a9a409d176282ab8847047e              NaN    2.799826
# 192ff60bd8841ae6727ed1861e60156b              NaN    0.000000
#
# expected_name                     xXx: State of the Union (2005)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                             NaN
# 73b13da703becd9ab9903197cf246dee                             NaN
# 35afcbf0c50ede54759a40183469178c                             NaN
# ea4734eb95ee46f675d5768919930cc2                             NaN
# 1c1286bced458836d6c082753a70facc                             NaN
# 08419a2991116300be4f440f45f1c71e                             NaN
# 655e9ec8da090890d4301410f5b8dee5                             NaN
# 29269716223ac43f3921533adce28fce                             NaN
# 15ba0b093a9a409d176282ab8847047e                             NaN
# 192ff60bd8841ae6727ed1861e60156b                             NaN
#
# expected_name                     ¡Three Amigos! (1986)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d                    NaN
# 73b13da703becd9ab9903197cf246dee                    NaN
# 35afcbf0c50ede54759a40183469178c                    NaN
# ea4734eb95ee46f675d5768919930cc2                    NaN
# 1c1286bced458836d6c082753a70facc                    NaN
# 08419a2991116300be4f440f45f1c71e                    NaN
# 655e9ec8da090890d4301410f5b8dee5                    NaN
# 29269716223ac43f3921533adce28fce                    NaN
# 15ba0b093a9a409d176282ab8847047e                    NaN
# 192ff60bd8841ae6727ed1861e60156b                    NaN
#
# expected_name                     À nous la liberté (Freedom for Us) (1931)
# userid
# 3f77830c1b96c0ce003e248a069cf61d                                        NaN
# 73b13da703becd9ab9903197cf246dee                                        NaN
# 35afcbf0c50ede54759a40183469178c                                        NaN
# ea4734eb95ee46f675d5768919930cc2                                        NaN
# 1c1286bced458836d6c082753a70facc                                        NaN
# 08419a2991116300be4f440f45f1c71e                                        NaN
# 655e9ec8da090890d4301410f5b8dee5                                        NaN
# 29269716223ac43f3921533adce28fce                                        NaN
# 15ba0b093a9a409d176282ab8847047e                                        NaN
# 192ff60bd8841ae6727ed1861e60156b                                        NaN
#
# [10 rows x 9546 columns]

# %%
test = ratings_pred_2_df.iloc[-1][~ratings_pred_2_df.iloc[0].isna()]
len(test.values[test.values!=0])
# Out:
# 128

# %%
test = similiar_ratings.iloc[-1][~similiar_ratings.iloc[0].isna()]
len(test.values[test.values!=0])
# Out:
# 76

# %% [markdown]
# 마지막 사용자에 대해서 50개 정도가 예상 점수로 추가되었다.

# %% [markdown]
# ---

# %%
# 영화 추천해주기 
ratings_pred_2_df = ratings_pred_2_df.dropna(axis=1)
ratings_pred_2_df
# Out:
# expected_name                     (500) Days of Summer (2009)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d
  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d            0.00       3.425580
# 73b13da703becd9ab9903197cf246dee            0.00       0.000000
# 35afcbf0c50ede54759a40183469178c            0.00       0.000000
# ea4734eb95ee46f675d5768919930cc2            0.00       0.539823
# 1c1286bced458836d6c082753a70facc            0.00       0.339617
# 08419a2991116300be4f440f45f1c71e            0.00       0.000000
# 655e9ec8da090890d4301410f5b8dee5            0.00       4.203524
# 29269716223ac43f3921533adce28fce            3.65       0.000000
# 15ba0b093a9a409d176282ab8847047e            0.00       4.113627
# 192ff60bd8841ae6727ed1861e60156b            0.00       0.000000
#
# expected_name                     Zombieland (2009)  Zoolander (2001)  \
# userid
# 3f77830c1b96c0ce003e248a069cf61d           0.000000          0.000000
# 73b13da703becd9ab9903197cf246dee           0.000000          0.000000
# 35afcbf0c50ede54759a40183469178c           0.000000          0.000000
# ea4734eb95ee46f675d5768919930cc2           3.850095          0.000000
# 1c1286bced458836d6c082753a70facc           0.000000          0.000000
# 08419a2991116300be4f440f45f1c71e           0.000000          0.000000
# 655e9ec8da090890d4301410f5b8dee5           2.899603          2.702020
# 29269716223ac43f3921533adce28fce           4.200590          0.000000
# 15ba0b093a9a409d176282ab8847047e           3.498095          0.303494
# 192ff60bd8841ae6727ed1861e60156b           0.000000          0.000000
#
# expected_name                     Zoom (2006)  Zootopia (2016)  xXx (2002)
# userid
# 3f77830c1b96c0ce003e248a069cf61d         0.00         4.542562    0.000000
# 73b13da703becd9ab9903197cf246dee         0.00         0.799741    0.000000
# 35afcbf0c50ede54759a40183469178c         0.00         0.000000    0.000000
# ea4734eb95ee46f675d5768919930cc2         0.00         4.542833    2.149820
# 1c1286bced458836d6c082753a70facc         0.00         0.377491    0.000000
# 08419a2991116300be4f440f45f1c71e         0.00         0.000000    0.000000
# 655e9ec8da090890d4301410f5b8dee5         0.00         0.952559    0.000000
# 29269716223ac43f3921533adce28fce         3.65         0.234225    0.000000
# 15ba0b093a9a409d176282ab8847047e         0.00         3.763822    2.799826
# 192ff60bd8841ae6727ed1861e60156b         0.00         0.237178    0.000000
#
# [10 rows x 1836 columns]

# %%
# np.std(ratings_pred_2_df.iloc[:,2][ratings_pred_2_df.iloc[:,2] >= 1])
# Out:
# 0.6726319101377147

# %%
# ratings_mean = np.mean(ratings_pred_2_df[ratings_pred_2_df.iloc[:,:] >= 1]).sort_values()[::-1]

# %%
ratings_mean = np.mean(ratings_pred_2_df).sort_values()[::-1]
ratings_mean
# Out:
# expected_name
# Matrix, The (1999)         3.614722
# Toy Story (1995)           3.598449
# Inception (2010)           3.497116
# Interstellar (2014)        3.430345
# Dark Knight, The (2008)    3.411243
#                              ...
# Smokin' Aces (2006)        0.305000
# Pay It Forward (2000)      0.305000
# Secret Window (2004)       0.305000
# Mist, The (2007)           0.300551
# Zoolander (2001)           0.300551
# Length: 1836, dtype: float64

# %%
print("추천 영화 10개 : \n")
print(ratings_mean[:10])
# Out:
# 추천 영화 10개 :
#
# expected_name
# Matrix, The (1999)                                       3.614722
# Toy Story (1995)                                         3.598449
# Inception (2010)                                         3.497116
# Interstellar (2014)                                      3.430345
# Dark Knight, The (2008)                                  3.411243
# Forrest Gump (1994)                                      3.272809
# Lord of the Rings: The Return of the King, The (2003)    3.253468
# American History X (1998)                                3.243913
# Memento (2000)                                           3.186190
# Shawshank Redemption, The (1994)                         3.132047
# dtype: float64
